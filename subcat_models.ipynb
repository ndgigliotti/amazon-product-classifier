# %%
import re
import string
import json
import os
import shutil
from pprint import pprint
from functools import partial
from operator import itemgetter, attrgetter
from os.path import normpath
from typing import Callable

import joblib
import matplotlib.pyplot as plt
import nltk
import numpy as np
import pandas as pd
import seaborn as sns
from gensim.parsing.preprocessing import STOPWORDS
from sacremoses import MosesTokenizer, MosesTruecaser
from sklearn.base import clone
from sklearn.compose import (
    ColumnTransformer,
    make_column_selector,
    make_column_transformer,
)
from sklearn.dummy import DummyClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.feature_selection import (
    VarianceThreshold,
    SelectKBest,
    SelectPercentile,
    GenericUnivariateSelect,
    f_classif,
    mutual_info_classif,
    chi2,
)
from sklearn.ensemble import StackingClassifier, VotingClassifier
from sklearn.neighbors import KNeighborsClassifier, RadiusNeighborsClassifier, NearestCentroid, NearestNeighbors
from sklearn.linear_model import (
    LogisticRegression,
    LogisticRegressionCV,
    PassiveAggressiveClassifier,
    Perceptron,
    RidgeClassifier,
    RidgeClassifierCV,
    SGDClassifier,
)
from sklearn.naive_bayes import (
    BernoulliNB,
    CategoricalNB,
    ComplementNB,
    GaussianNB,
    MultinomialNB,
)
from sklearn.svm import LinearSVC, NuSVC, OneClassSVM, SVC
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import (
    GridSearchCV,
    RandomizedSearchCV,
    RepeatedStratifiedKFold,
    StratifiedKFold,
    train_test_split,
)
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.impute import KNNImputer
# from sklearn.pipeline import FeatureUnion, Pipeline, make_pipeline
from imblearn.pipeline import Pipeline
from imblearn.over_sampling import SMOTE, SMOTENC
from sklearn.preprocessing import (
    OneHotEncoder,
    Binarizer,
    FunctionTransformer,
    MaxAbsScaler,
    MinMaxScaler,
    minmax_scale,
    Normalizer,
    normalize,
    PowerTransformer,
    QuantileTransformer,
    RobustScaler,
    StandardScaler,
    PolynomialFeatures,
    MultiLabelBinarizer,
)
import sklearn.utils as skl_utils
from sklearn.metrics import accuracy_score, balanced_accuracy_score, classification_report

import dask
import dask.dataframe as dd

# Set Seaborn theme and default palette
sns.set_theme(font_scale=1.25, style="darkgrid")
sns.set_palette("deep", desat=0.85, color_codes=True)

# Turn on inline plotting
# %matplotlib inline

# Load Black auto-formatter
# %load_ext nb_black

# %%
# Import my modules
from tools import cleaning, plotting, language as lang, outliers, utils
from tools.sklearn.vectorizers import FreqVectorizer, Doc2Vectorizer, AverageVectorizer
from tools.sklearn.classification import diagnostics as diag
from tools.sklearn import selection

# Run time-consuming grid searches
RUN_SWEEPS = True

# Set my default MPL settings
plt.rcParams.update(plotting.MPL_DEFAULTS)

# Enable automatic reloading
# %load_ext autoreload
# %autoreload 2

# %%
df = pd.read_parquet("data/model_text", engine="pyarrow")
display(df.head())
df.shape
# Out:
#                                                          text  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# 8867326759  moleskine payne's grey card wallet (moleskine ...
# 9623402791  hello kitty taupe embossed face wallet loungef...
# 9742121109  estee lauder resilience lift night firming/scu...
# B00004TUBN  better living the dispenser classic chrome iii...
#
#                                                         title        brand  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...   bonballoon
# 8867326759  moleskine payne's grey card wallet (moleskine ...    sunatoria
# 9623402791  hello kitty taupe embossed face wallet loungef...  hello_kitty
# 9742121109  estee lauder resilience lift night firming/scu...         chom
# B00004TUBN     better living the dispenser classic chrome iii      classic
#
#                                                       sub_cat    main_cat
# asin
# 6090113980  [home & kitchen, home dcor, area rugs, runners...  all beauty
# 8867326759                                               None  all beauty
# 9623402791                                               None  all beauty
# 9742121109                                               None  all beauty
# B00004TUBN  [home & kitchen, bathroom accessories, holders...  all beauty
# (2814882, 5)

# %%
df = df.dropna(subset=["sub_cat"])
df
# Out:
#                                                          text  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN  better living the dispenser classic chrome iii...
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD  sonicare pl-4 (4700) sonic toothbrush. you cou...
# B000050FDE  oral-b professional care 1000 power toothbrush...
# ...                                                       ...
# B01HJ149LI  god eater resurrection - ps vita [digital code...
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0  the technomancer - ps4 [digital code]. the tec...
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                                                         title  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN     better living the dispenser classic chrome iii
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD              sonicare pl-4 (4700) sonic toothbrush
# B000050FDE     oral-b professional care 1000 power toothbrush
# ...                                                       ...
# B01HJ149LI    god eater resurrection - ps vita [digital code]
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0              the technomancer - ps4 [digital code]
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                              brand  \
# asin
# 6090113980              bonballoon
# B00004TUBN                 classic
# B000050AP3          hamilton_beach
# B000050AUD                 philips
# B000050FDE                  oral_b
# ...                            ...
# B01HJ149LI                  bandai
# B01HJ14FDA                  bandai
# B01HJ14OT0  focus_home_interactive
# B01HJ14TTA             warner_bros
# B01HJ1521Y             warner_bros
#
#                                                       sub_cat     main_cat
# asin
# 6090113980  [home & kitchen, home dcor, area rugs, runners...   all beauty
# B00004TUBN  [home & kitchen, bathroom accessories, holders...   all beauty
# B000050AP3  [home & kitchen, heating, cooling & air qualit...   all beauty
# B000050AUD  [industrial & scientific, professional dental ...   all beauty
# B000050FDE  [industrial & scientific, professional dental ...   all beauty
# ...                                                       ...          ...
# B01HJ149LI  [video games, playstation vita, digital games ...  video games
# B01HJ14FDA  [video games, playstation 4, digital games & d...  video games
# B01HJ14OT0  [video games, playstation 4, digital games & d...  video games
# B01HJ14TTA  [video games, playstation 4, digital games & d...  video games
# B01HJ1521Y  [video games, playstation vita, digital games ...  video games
#
# [2722710 rows x 5 columns]

# %%
df.main_cat.value_counts().to_frame().style.bar()
# Out:
# <style  type="text/css" >
# #T_b8166_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_b8166_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.3%, transparent 78.3%);
#         }#T_b8166_row2_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 52.2%, transparent 52.2%);
#         }#T_b8166_row3_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.6%, transparent 42.6%);
#         }#T_b8166_row4_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.6%, transparent 41.6%);
#         }#T_b8166_row5_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 40.0%, transparent 40.0%);
#         }#T_b8166_row6_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.9%, transparent 20.9%);
#         }#T_b8166_row7_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.1%, transparent 16.1%);
#         }#T_b8166_row8_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.0%, transparent 16.0%);
#         }#T_b8166_row9_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.5%, transparent 15.5%);
#         }#T_b8166_row10_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.7%, transparent 14.7%);
#         }#T_b8166_row11_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.6%, transparent 11.6%);
#         }#T_b8166_row12_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.4%, transparent 11.4%);
#         }#T_b8166_row13_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.6%, transparent 9.6%);
#         }#T_b8166_row14_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.2%, transparent 9.2%);
#         }#T_b8166_row15_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.7%, transparent 7.7%);
#         }#T_b8166_row16_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.0%, transparent 7.0%);
#         }#T_b8166_row17_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.3%, transparent 4.3%);
#         }#T_b8166_row18_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.1%, transparent 4.1%);
#         }#T_b8166_row19_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }#T_b8166_row20_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.9%, transparent 1.9%);
#         }#T_b8166_row21_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.6%, transparent 1.6%);
#         }#T_b8166_row22_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.4%, transparent 1.4%);
#         }#T_b8166_row23_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 1.1%, transparent 1.1%);
#         }#T_b8166_row24_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.8%, transparent 0.8%);
#         }#T_b8166_row25_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.6%, transparent 0.6%);
#         }#T_b8166_row26_col0,#T_b8166_row27_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.5%, transparent 0.5%);
#         }#T_b8166_row28_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.4%, transparent 0.4%);
#         }#T_b8166_row29_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.2%, transparent 0.2%);
#         }#T_b8166_row30_col0{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_b8166_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >main_cat</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_b8166_level0_row0" class="row_heading level0 row0" >amazon home</th>
#                         <td id="T_b8166_row0_col0" class="data row0 col0" >530265</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row1" class="row_heading level0 row1" >amazon fashion</th>
#                         <td id="T_b8166_row1_col0" class="data row1 col0" >415093</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row2" class="row_heading level0 row2" >sports & outdoors</th>
#                         <td id="T_b8166_row2_col0" class="data row2 col0" >276602</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row3" class="row_heading level0 row3" >toys & games</th>
#                         <td id="T_b8166_row3_col0" class="data row3 col0" >225656</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row4" class="row_heading level0 row4" >automotive</th>
#                         <td id="T_b8166_row4_col0" class="data row4 col0" >220492</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row5" class="row_heading level0 row5" >tools & home improvement</th>
#                         <td id="T_b8166_row5_col0" class="data row5 col0" >211979</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row6" class="row_heading level0 row6" >cell phones & accessories</th>
#                         <td id="T_b8166_row6_col0" class="data row6 col0" >110820</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row7" class="row_heading level0 row7" >computers</th>
#                         <td id="T_b8166_row7_col0" class="data row7 col0" >85353</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row8" class="row_heading level0 row8" >grocery</th>
#                         <td id="T_b8166_row8_col0" class="data row8 col0" >84664</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row9" class="row_heading level0 row9" >office products</th>
#                         <td id="T_b8166_row9_col0" class="data row9 col0" >82073</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row10" class="row_heading level0 row10" >arts, crafts & sewing</th>
#                         <td id="T_b8166_row10_col0" class="data row10 col0" >78077</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row11" class="row_heading level0 row11" >all electronics</th>
#                         <td id="T_b8166_row11_col0" class="data row11 col0" >61317</td>
#             </tr>
#             <tr>
#                         <th id="T_b8166_level0_row12" class="row_heading level0 row12" >industrial & scientific</th>
#                         <td id="T_b8166_row12_col0" class="data row12

# %%
df = utils.prune_categories(df, "main_cat", 1000)
df
# Out:
#                          Dropped
# collectibles & fine art      884
# prime pantry                   7
#                                                          text  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN  better living the dispenser classic chrome iii...
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD  sonicare pl-4 (4700) sonic toothbrush. you cou...
# B000050FDE  oral-b professional care 1000 power toothbrush...
# ...                                                       ...
# B01HJ149LI  god eater resurrection - ps vita [digital code...
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0  the technomancer - ps4 [digital code]. the tec...
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                                                         title  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN     better living the dispenser classic chrome iii
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD              sonicare pl-4 (4700) sonic toothbrush
# B000050FDE     oral-b professional care 1000 power toothbrush
# ...                                                       ...
# B01HJ149LI    god eater resurrection - ps vita [digital code]
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0              the technomancer - ps4 [digital code]
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                              brand  \
# asin
# 6090113980              bonballoon
# B00004TUBN                 classic
# B000050AP3          hamilton_beach
# B000050AUD                 philips
# B000050FDE                  oral_b
# ...                            ...
# B01HJ149LI                  bandai
# B01HJ14FDA                  bandai
# B01HJ14OT0  focus_home_interactive
# B01HJ14TTA             warner_bros
# B01HJ1521Y             warner_bros
#
#                                                       sub_cat     main_cat
# asin
# 6090113980  [home & kitchen, home dcor, area rugs, runners...   all beauty
# B00004TUBN  [home & kitchen, bathroom accessories, holders...   all beauty
# B000050AP3  [home & kitchen, heating, cooling & air qualit...   all beauty
# B000050AUD  [industrial & scientific, professional dental ...   all beauty
# B000050FDE  [industrial & scientific, professional dental ...   all beauty
# ...                                                       ...          ...
# B01HJ149LI  [video games, playstation vita, digital games ...  video games
# B01HJ14FDA  [video games, playstation 4, digital games & d...  video games
# B01HJ14OT0  [video games, playstation 4, digital games & d...  video games
# B01HJ14TTA  [video games, playstation 4, digital games & d...  video games
# B01HJ1521Y  [video games, playstation vita, digital games ...  video games
#
# [2721819 rows x 5 columns]

# %%
min_support = 0.001

pruned_df = []

for i, (main_cat, cat_df) in enumerate(df.groupby("main_cat")):
    cat_df = cat_df.explode("sub_cat")
    cat_df = utils.prune_categories(
        cat_df,
        "sub_cat",
        min_support,
        show_report=False,
    )
    cat_df = utils.implode(cat_df, "sub_cat")
    train, test = train_test_split(cat_df, random_state=i)
    cat_df["test_set"] = cat_df.index.isin(test.index)
    pruned_df.append(cat_df)

pruned_df = pd.concat(pruned_df, axis=0)
pruned_df
# Out:
#                                                          text  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN  better living the dispenser classic chrome iii...
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD  sonicare pl-4 (4700) sonic toothbrush. you cou...
# B000050FDE  oral-b professional care 1000 power toothbrush...
# ...                                                       ...
# B01HJ149LI  god eater resurrection - ps vita [digital code...
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0  the technomancer - ps4 [digital code]. the tec...
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                                                         title  \
# asin
# 6090113980  prayer rug carpet mat gebetsteppich islamic mu...
# B00004TUBN     better living the dispenser classic chrome iii
# B000050AP3  hamilton beach 05521 trueair 3.5 gal. cool mis...
# B000050AUD              sonicare pl-4 (4700) sonic toothbrush
# B000050FDE     oral-b professional care 1000 power toothbrush
# ...                                                       ...
# B01HJ149LI    god eater resurrection - ps vita [digital code]
# B01HJ14FDA  jojo eyes of heaven complete bundle - ps4 [dig...
# B01HJ14OT0              the technomancer - ps4 [digital code]
# B01HJ14TTA  lego star wars: the force awakens season pass ...
# B01HJ1521Y  lego star wars: the force awakens - ps vita [d...
#
#                              brand  \
# asin
# 6090113980              bonballoon
# B00004TUBN                 classic
# B000050AP3          hamilton_beach
# B000050AUD                 philips
# B000050FDE                  oral_b
# ...                            ...
# B01HJ149LI                  bandai
# B01HJ14FDA                  bandai
# B01HJ14OT0  focus_home_interactive
# B01HJ14TTA             warner_bros
# B01HJ1521Y             warner_bros
#
#                                                       sub_cat     main_cat  \
# asin
# 6090113980                        [home & kitchen, home dcor]   all beauty
# B00004TUBN  [home & kitchen, bathroom accessories, holders...   all beauty
# B000050AP3   [home & kitchen, heating, cooling & air quality]   all beauty
# B000050AUD  [industrial & scientific, professional dental ...   all beauty
# B000050FDE  [industrial & scientific, professional dental ...   all beauty
# ...                                                       ...          ...
# B01HJ149LI  [video games, playstation vita, digital games ...  video games
# B01HJ14FDA  [video games, playstation 4, digital games & d...  video games
# B01HJ14OT0  [video games, playstation 4, digital games & d...  video games
# B01HJ14TTA  [video games, playstation 4, digital games & d...  video games
# B01HJ1521Y  [video games, playstation vita, digital games ...  video games
#
#             test_set
# asin
# 6090113980     False
# B00004TUBN      True
# B000050AP3     False
# B000050AUD     False
# B000050FDE      True
# ...              ...
# B01HJ149LI     False
# B01HJ14FDA      True
# B01HJ14OT0     False
# B01HJ14TTA     False
# B01HJ1521Y     False
#
# [2693138 rows x 6 columns]

# %% [markdown]
# # Modeling
# ## Train-Test Split

# %%
mlb = MultiLabelBinarizer()

# %%
main_category = "video games"

# Index by 'main_cat'
if pruned_df.index.name != "main_cat":
    pruned_df.set_index("main_cat", inplace=True)

# Prepare train and test masks
test = pruned_df.loc[main_category, "test_set"]
train = ~test

# Define X and y
X = pruned_df.loc[main_category, "text"]
y = pruned_df.loc[main_category, "sub_cat"]
y = mlb.fit_transform(y)

# Slice out train and test sets
X_train = X[train]
X_test = X[test]
y_train = y[train]
y_test = y[test]

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((16830,), (5611,), (16830, 50), (5611, 50))

# %%
mlb.classes_
# Out:
# array(['40 objects per level', 'accessories', 'accessory kits',
#        'batteries & chargers', 'cables', 'cables & adapters',
#        'cases & storage', 'chargers', "children's",
#        'clothing, shoes & jewelry', 'computers & accessories', 'consoles',
#        'controllers', 'currency & subscription cards', 'digital games',
#        'digital games & dlc', 'downloadable content', 'electronics',
#        'faceplates, protectors & skins', 'game boy advance',
#        'game boy color', 'gamecube', 'gamepads & standard controllers',
#        'games', 'headsets', 'interactive gaming figures', 'kids & family',
#        'nintendo 3ds', 'nintendo 3ds & 2ds', 'nintendo 64', 'nintendo ds',
#        'nintendo nes', 'playstation', 'playstation 2', 'playstation 3',
#        'playstation 4', 'playstation vita', 'remotes',
#        'retro gaming & microconsoles', 'sega dreamcast', 'sega genesis',
#        'skins', 'software', 'sony psp', 'super nintendo', 'toys & games',
#        'video games', 'wii u', 'xbox 360', 'xbox one'], dtype=object)

# %%
fv = FreqVectorizer(
    lowercase=False,
    decode_html_entities=False,
)

fv
# Out:
# FreqVectorizer(decode_html_entities=False, lowercase=False)

# %%
pipe = Pipeline(
    [
        ("vec", fv),
        ("cls", "passthrough"),
    ],
    memory="pipeline_cache",
)
pipe
# Out:
# Pipeline(memory='pipeline_cache',
#          steps=[('vec',
#                  FreqVectorizer(decode_html_entities=False, lowercase=False)),
#                 ('cls', 'passthrough')])

# %%
pipe.fit_transform(X_train, y_train)
# Out:
# <16830x55470 sparse matrix of type '<class 'numpy.float64'>'
# 	with 1889121 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # Baseline RF

# %%
def print_report(pipe, X_test=X_test, y_test=y_test):
    print(
        classification_report(y_test, pipe.predict(X_test), target_names=mlb.classes_)
    )

# %%
rf = RandomForestClassifier(n_jobs=-1)

pipe.set_params(cls=rf)
pipe.fit(X_train, y_train)
print_report(pipe)
# Out:
# C:\Users\ndgig\Anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\ndgig\Anaconda3\envs\learn-env\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                  precision    recall  f1-score   support
#
#            40 objects per level       1.00      0.93      0.96        27
#                     accessories       0.94      0.92      0.93      1062
#                  accessory kits       1.00      0.17      0.29        81
#            batteries & chargers       0.97      0.32      0.48        92
#                          cables       1.00      0.15      0.26        54
#               cables & adapters       1.00      0.13      0.22        71
#                 cases & storage       1.00      0.41      0.59       116
#                        chargers       0.90      0.13      0.23        67
#                      children's       1.00      0.43      0.60       109
#       clothing, shoes & jewelry       1.00      0.83      0.90        23
#         computers & accessories       0.00      0.00      0.00        33
#                        consoles       0.94      0.18      0.30        83
#                     controllers       0.95      0.21      0.35       184
#   currency & subscription cards       0.93      0.67      0.78        21
#                   digital games       1.00      0.15      0.25        62
#             digital games & dlc       0.98      0.78      0.87       231
#            downloadable content       1.00      0.48      0.64        61
#                     electronics       0.00      0.00      0.00        52
#  faceplates, protectors & skins       1.00      0.58      0.73        71
#                game boy advance       0.97      0.23      0.38       162
#                  game boy color       0.00      0.00      0.00        72
#                        gamecube       0.00      0.00      0.00        91
# gamepads & standard controllers       0.80      0.08      0.14        52
#                           games       0.93      0.99      0.96      3949
#                        headsets       1.00      0.20      0.34        49
#      interactive gaming figures       1.00      0.33      0.50        18
#                   kids & family       1.00      0.73      0.84       599
#                    nintendo 3ds       1.00      0.12      0.21        43
#              nintendo 3ds & 2ds       0.87      0.25      0.39       102
#                     nintendo 64       1.00      0.04      0.08        48
#                     nintendo ds       0.99      0.53      0.69       377
#                    nintendo nes       0.75      0.12      0.21        24
#                     playstation       0.00      0.00      0.00       150
#                   playstation 2       0.97      0.08      0.16       331
#                   playstation 3       0.88      0.13      0.23       402
#                   playstation 4       0.98      0.24      0.39       221
#                playstation vita       1.00      0.08      0.14        65
#                         remotes       0.00      0.00      0.00        21
#    retro gaming & microconsoles       1.00      0.97      0.98      1262
#                  sega dreamcast       1.00      0.17      0.29        36
#                    sega genesis       1.00      0.29      0.44        42
#                           skins       0.92      0.60      0.73        20
#                        software       1.00      0.42      0.59       125
#                        sony psp       1.00      0.09      0.16       185
#                  super nintendo       1.00      0.08      0.15        48
#                    toys & games       1.00      0.21      0.35        43
#                     video games       0.98      1.00      0.99      5362
#                           wii u       0.60      0.05      0.09        64
#                        xbox 360       0.88      0.21      0.34       347
#                        xbox one       1.00      0.19      0.32       202
#
#                       micro avg       0.96      0.77      0.86     17012
#                       macro avg       0.84      0.32      0.41     17012
#                    weighted avg       0.94      0.77      0.80     17012
#                     samples avg       0.95      0.80      0.85     17012

# %%
cls_grid = (
    {
        "cls": [
            ExtraTreesClassifier(),
            RandomForestClassifier(),
            DecisionTreeClassifier(),
            RidgeClassifierCV(),
            KNeighborsClassifier(),
            RadiusNeighborsClassifier(),
            DummyClassifier(strategy="stratified"),
        ],
        "vec__use_idf": [True, False],
        "vec__binary": [True, False],
        "vec__norm": ["l1", "l2", None],
    },
)


cls_grid
# Out:
# ({'cls': [ExtraTreesClassifier(),
#    RandomForestClassifier(),
#    DecisionTreeClassifier(),
#    RidgeClassifierCV(alphas=array([ 0.1,  1. , 10. ])),
#    KNeighborsClassifier(),
#    RadiusNeighborsClassifier(),
#    DummyClassifier(strategy='stratified')],
#   'vec__use_idf': [True, False],
#   'vec__binary': [True, False],
#   'vec__norm': ['l1', 'l2', None]},)

# %%
if RUN_SWEEPS:
    gs = selection.sweep(
        pipe,
        cls_grid,
        X=X_train,
        y=y_train,
        dst="sweeps/multilabel_classifier",
        n_jobs=-1,
        scoring="f1_weighted",
    )

gs
# Out:
# Fitting 5 folds for each of 84 candidates, totalling 420 fits
# C:\Users\ndgig\Anaconda3\envs\learn-env\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [0.68050168 0.68484264 0.69515499 0.70546555 0.73009235 0.73036295
#  0.66708968 0.66716895 0.68136358 0.67380991 0.69363692 0.69621121
#  0.7153277  0.71577855 0.71718018 0.71863208 0.71879868 0.72216398
#  0.71292077 0.71845844 0.71748793 0.71681718 0.7222084  0.72208574
#  0.91177796 0.91171831 0.91283546 0.91330332 0.91584351 0.91871352
#  0.91394281 0.91431842 0.91771399 0.91226247 0.92049479 0.92239214
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.62504635 0.70080573 0.75301039 0.79445163 0.60381919 0.72575729
#  0.67361248 0.68342516 0.71495063 0.70637199 0.66150614 0.67880568
#  0.50586904 0.50586904        nan        nan        nan        nan
#  0.50586904 0.50586904        nan        nan        nan        nan
#  0.50520114 0.50608696 0.50568603 0.50779702 0.50686636 0.50762224
#  0.50755745 0.50555794 0.50570379 0.50669675 0.50606832 0.50544745]
#   warnings.warn(
# 'sweeps\\multilabel_classifier.joblib'
# GridSearchCV(estimator=Pipeline(memory='pipeline_cache',
#                                 steps=[('vec',
#                                         FreqVectorizer(decode_html_entities=False,
#                                                        lowercase=False)),
#                                        ('cls',
#                                         RandomForestClassifier(n_jobs=-1))]),
#              n_jobs=-1,
#              param_grid=[{'cls': [ExtraTreesClassifier(),
#                                   RandomForestClassifier(),
#                                   DecisionTreeClassifier(),
#                                   RidgeClassifierCV(alphas=array([ 0.1,  1. , 10. ])),
#                                   KNeighborsClassifier(),
#                                   RadiusNeighborsClassifier(),
#                                   DummyClassifier(strategy='stratified')],
#                           'vec__binary': [True, False],
#                           'vec__norm': ['l1', 'l2', None],
#                           'vec__use_idf': [True, False]}],
#              scoring='f1_weighted', verbose=1)

# %%
cv_results = selection.prune_cv(gs.cv_results_)
cv_results.head(15)
# Out:
#                    param_cls  binary  norm  use_idf  \
# 0   DecisionTreeClassifier()   False  None    False
# 1   DecisionTreeClassifier()   False  None     True
# 2   DecisionTreeClassifier()    True  None    False
# 3   DecisionTreeClassifier()   False    l2     True
# 4   DecisionTreeClassifier()    True  None     True
# 5   DecisionTreeClassifier()   False    l1    False
# 6   DecisionTreeClassifier()   False    l1     True
# 7   DecisionTreeClassifier()    True    l2    False
# 8   DecisionTreeClassifier()    True    l2     True
# 9   DecisionTreeClassifier()   False    l2    False
# 10  DecisionTreeClassifier()    True    l1     True
# 11  DecisionTreeClassifier()    True    l1    False
# 12    KNeighborsClassifier()    True    l2    False
# 13    KNeighborsClassifier()    True    l2     True
# 14    ExtraTreesClassifier()    True  None    False
#
#                                                params  mean_fit_time  \
# 0   {'cls': DecisionTreeClassifier(), 'vec__binary...      26.677168
# 1   {'cls': DecisionTreeClassifier(), 'vec__binary...      25.249241
# 2   {'cls': DecisionTreeClassifier(), 'vec__binary...      28.083394
# 3   {'cls': DecisionTreeClassifier(), 'vec__binary...      52.778937
# 4   {'cls': DecisionTreeClassifier(), 'vec__binary...      28.074500
# 5   {'cls': DecisionTreeClassifier(), 'vec__binary...      60.487655
# 6   {'cls': DecisionTreeClassifier(), 'vec__binary...      67.687819
# 7   {'cls': DecisionTreeClassifier(), 'vec__binary...      56.575219
# 8   {'cls': DecisionTreeClassifier(), 'vec__binary...      67.734212
# 9   {'cls': DecisionTreeClassifier(), 'vec__binary...      59.380020
# 10  {'cls': DecisionTreeClassifier(), 'vec__binary...      70.366306
# 11  {'cls': DecisionTreeClassifier(), 'vec__binary...      56.241724
# 12  {'cls': KNeighborsClassifier(), 'vec__binary':...       0.679401
# 13  {'cls': KNeighborsClassifier(), 'vec__binary':...       0.744399
# 14  {'cls': ExtraTreesClassifier(), 'vec__binary':...     172.248223
#
#     mean_score  rank_score
# 0     0.922392           1
# 1     0.920495           2
# 2     0.918714           3
# 3     0.917714           4
# 4     0.915844           5
# 5     0.914318           6
# 6     0.913943           7
# 7     0.913303           8
# 8     0.912835           9
# 9     0.912262          10
# 10    0.911778          11
# 11    0.911718          12
# 12    0.794452          13
# 13    0.753010          14
# 14    0.730363          15
